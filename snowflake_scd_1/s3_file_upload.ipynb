# %%
pip install boto3 yml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: boto3 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (1.21.32)
# Collecting yml
#   Downloading yml-0.0.1.tar.gz (1.2 kB)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from boto3) (0.5.0)
# Requirement already satisfied: botocore<1.25.0,>=1.24.32 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from boto3) (1.24.32)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from boto3) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from botocore<1.25.0,>=1.24.32->boto3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from botocore<1.25.0,>=1.24.32->boto3) (1.26.9)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.25.0,>=1.24.32->boto3) (1.16.0)
# Building wheels for collected packages: yml
#   Building wheel for yml (setup.py) ... done
#   Created wheel for yml: filename=yml-0.0.1-py3-none-any.whl size=1375 sha256=842652c7da18e8a577d4abadd99c9a326e78ccebbb84983ab51ad48bac319623
#   Stored in directory: /home/e8d5fce4-542a-4acb-9c21-71e613a87843/.cache/pip/wheels/73/04/ec/2c8f8f894a749c526bdadd9688e2fddd613fcd5608030a727d
# Successfully built yml
# Installing collected packages: yml
# Successfully installed yml-0.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
import yaml

with open('aws_credentials.yml', 'r') as file:
    aws_credentials = yaml.safe_load(file)

# Extract credentials from YAML
aws_access_key_id = aws_credentials['aws_access_key_id']
aws_secret_access_key = aws_credentials['aws_secret_access_key']
aws_region_name = aws_credentials['aws_region_name']

# Initialize a session using AWS credentials
session = boto3.Session(
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=aws_region_name
)

#Update the below variables values with your details
file_name = 'scd1_customer_change_data.csv'
bucket_name = 'snowflake-scd1-project-bucket'
folder_name = 'data'

# Create an S3 client
s3_client = session.client('s3')

try: 
    # Upload file in S3
    s3_client.upload_file( 
    Filename =file_name, 
    Bucket=bucket_name, 
    Key=folder_name + '/' + file_name
    )

    print(file_name + " is uploaded sucessfully")
except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# scd1_customer_change_data.csv is uploaded sucessfully
